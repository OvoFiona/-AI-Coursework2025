# %% [markdown]
# <a href="https://colab.research.google.com/github/OvoFiona/-AI-Coursework2025/blob/main/Netflix_Titles_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

# Upload and load the file
uploaded = files.upload()
filename = list(uploaded.keys())[0]
df = pd.read_csv(filename)

# How many rows and columns are contained in the dataset?
print(f"\nColumn names: {list(df.columns)}")
print(f"\nRow no: {list(df.shape)}")
# Out:
#      <input type="file" id="files-66ed12eb-5d68-4e41-b638-a73a0ef9b795" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66ed12eb-5d68-4e41-b638-a73a0ef9b795">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

# Upload and load the file
uploaded = files.upload()
filename = list(uploaded.keys())[0]
df = pd.read_csv(filename)

# What datatypes are contained in the dataset?
print("Datatypes in the dataset:")
print(df.dtypes)
# Out:
#      <input type="file" id="files-2092aba6-7a53-414e-97ea-5c37a3aefb53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2092aba6-7a53-414e-97ea-5c37a3aefb53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

# Upload and load the file
uploaded = files.upload()
filename = list(uploaded.keys())[0]
df = pd.read_csv(filename)

# Is the dataset complete? i.e no missing values?
is_complete = df.isnull().sum().sum() == 0
print(f"Is the dataset complete? {is_complete}")

missing_values = df.isnull().sum()
print("Missing values:")
print(missing_values)
# Out:
#      <input type="file" id="files-8d11cbef-9f09-463a-88f6-7269103b439a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d11cbef-9f09-463a-88f6-7269103b439a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

# Upload and load the file
uploaded = files.upload()
filename = list(uploaded.keys())[0]
df = pd.read_csv(filename)

# List the number of Movies and TV Shows among the last 20 rows of the dataset.
last_20 = df.tail(20)
print("Last 20 rows:")
print(df.tail(20)['type'].value_counts())
# Out:
#      <input type="file" id="files-44dfe420-b087-4de9-8e94-41c247615ad3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44dfe420-b087-4de9-8e94-41c247615ad3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

# Upload and load the file
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Give the number of all Movies originating from South Africa
print("Movies from South Africa")
sa_movies = df[(df['type'] == 'Movie') & (df['country'] == 'South Africa')]
count = len(sa_movies)

print(f"Number of movies from South Africa: {count}")
# Out:
#      <input type="file" id="files-51d861ee-e791-4098-ac29-4ed169cf6de5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51d861ee-e791-4098-ac29-4ed169cf6de5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

# Upload and load the file
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# What is the description of the movie in the 12th row?
row_12 = df.iloc[11]

print(f"Title: {row_12['title']}")
print(f"Type: {row_12['type']}")
print(f"Description: {row_12['description']}")
# Out:
#      <input type="file" id="files-4bf2a582-7161-4bec-9a76-5caa58ddbbf0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4bf2a582-7161-4bec-9a76-5caa58ddbbf0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

# Upload and load the file
uploaded = files.upload()
filename = list(uploaded.keys())[0]

#  From these South African movies, list only those released in 2021
sa_2021_movies = df[(df['type'] == 'Movie') & (df['country'] == 'South Africa') & (df['release_year'] == 2021)]
print(f"Number of South African movies from 2021: {len(sa_2021_movies)}")
if len(sa_2021_movies) > 0:
  print(sa_2021_movies[['title', 'release_year']].to_string(index=False))
# Out:
#      <input type="file" id="files-c96cb059-4164-4b87-9849-c64725d75e1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c96cb059-4164-4b87-9849-c64725d75e1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

# Upload and load the file
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# List the entire cast of all movies released in 2021.
movies_2021 = df[(df['type'] == 'Movie') & (df['release_year'] == 2021)]
print(f"Total movies from 2021: {len(movies_2021)}\n")
if len(movies_2021) >0:
  for idx, movie in movies_2021.iterrows():
    print(f"{movie['title']}")
    print(f"Cast: {movie['cast'] if pd.notna(movie['cast']) else 'Not available'}")
# Out:
#      <input type="file" id="files-870ddc35-dd94-4af2-937f-54ebe2abc99f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-870ddc35-dd94-4af2-937f-54ebe2abc99f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ![Lab 4 Group photo.jpeg](data:image/jpeg;base64,...)
